# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np
import sys
# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames
# Gestión de los warnings
# -------------------------------------------------
import warnings
warnings.filterwarnings("ignore")
import os
# Importaciones funciones propias
# -------------------------------------------------

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
 sys.path.append(project_root)

# %%
df_activity = pd.read_csv(r'../Files/Customer Flight Activity.csv', index_col=0)

# %%
sp_eda.exploracion_basica(df_activity)
# Out:
# ### Información general del DataFrame ###
# Forma (filas, columnas): (405624, 9)
# Columnas: ['Year', 'Month', 'Flights Booked', 'Flights with Companions', 'Total Flights', 'Distance', 'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed']
#
# Resumen info():
# <class 'pandas.core.frame.DataFrame'>
# Index: 405624 entries, 100018 to 999986
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Year                         405624 non-null  int64
#  1   Month                        405624 non-null  int64
#  2   Flights Booked               405624 non-null  int64
#  3   Flights with Companions      405624 non-null  int64
#  4   Total Flights                405624 non-null  int64
#  5   Distance                     405624 non-null  int64
#  6   Points Accumulated           405624 non-null  float64
#  7   Points Redeemed              405624 non-null  int64
# ...

# %%
df_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 405624 entries, 100018 to 999986
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Year                         405624 non-null  int64
#  1   Month                        405624 non-null  int64
#  2   Flights Booked               405624 non-null  int64
#  3   Flights with Companions      405624 non-null  int64
#  4   Total Flights                405624 non-null  int64
#  5   Distance                     405624 non-null  int64
#  6   Points Accumulated           405624 non-null  float64
#  7   Points Redeemed              405624 non-null  int64
#  8   Dollar Cost Points Redeemed  405624 non-null  int64
# dtypes: float64(1), int64(8)
# memory usage: 30.9 MB

# %% [markdown]
# A simple vista, no hay valores nulos y el tipo de dato parece correcto.

# %%
df_activity.head()
# Out:
#                 Year  Month  Flights Booked  Flights with Companions  \
# Loyalty Number
# 100018          2017      1               3                        0
# 100102          2017      1              10                        4
# 100140          2017      1               6                        0
# 100214          2017      1               0                        0
# 100272          2017      1               0                        0
#
#                 Total Flights  Distance  Points Accumulated  Points Redeemed  \
# Loyalty Number
# 100018                      3      1521               152.0                0
# 100102                     14      2030               203.0                0
# 100140                      6      1200               120.0                0
# 100214                      0         0                 0.0                0
# 100272                      0         0                 0.0                0
#
#                 Dollar Cost Points Redeemed
# ...

# %%
sp_eda.exploracion_num(df_activity,'Month', graficos=False, mostrar_estadisticas=False, mostrar_outliers=False)
# Out:
# La columna 'Month' es de tipo int64.
# El número total de valores únicos es de 12.
# Los valores únicos son: [ 1  9  2  3 11  4  5  7  6  8 10 12]
# --------------------------------------------------------------------------
# return - stats dict:
# {'min': np.int64(1),
#  'max': np.int64(12),
#  'mean': np.float64(6.5),
#  'median': np.float64(6.5),
#  'std': np.float64(3.45),
#  'percentil_25': np.float64(3.75),
#  'percentil_75': np.float64(9.25)}

# %%
sp_eda.exploracion_num(df_activity,'Flights Booked', graficos=False, mostrar_estadisticas=False, mostrar_outliers=False)
# Out:
# La columna 'Flights Booked' es de tipo int64.
# El número total de valores únicos es de 22.
# Hay muchos valores únicos, aquí algunos ejemplos: [ 3 10  6  0  8 11  9  4  7  5  2  1 12 13 14 16 15 17 18 19]
# --------------------------------------------------------------------------
# return - stats dict:
# {'min': np.int64(0),
#  'max': np.int64(21),
#  'mean': np.float64(4.12),
#  'median': np.float64(1.0),
#  'std': np.float64(5.23),
#  'percentil_25': np.float64(0.0),
#  'percentil_75': np.float64(8.0)}

# %%
sp_eda.exploracion_num(df_activity,'Flights with Companions', graficos=False, mostrar_estadisticas=False, mostrar_outliers=False)
# Out:
# La columna 'Flights with Companions' es de tipo int64.
# El número total de valores únicos es de 12.
# Los valores únicos son: [ 0  4  7  1  6  3  5  2 10  8  9 11]
# --------------------------------------------------------------------------
# return - stats dict:
# {'min': np.int64(0),
#  'max': np.int64(11),
#  'mean': np.float64(1.03),
#  'median': np.float64(0.0),
#  'std': np.float64(2.08),
#  'percentil_25': np.float64(0.0),
#  'percentil_75': np.float64(1.0)}

# %%
sp_eda.exploracion_num(df_activity,'Total Flights', graficos=False, mostrar_estadisticas=False, mostrar_outliers=False)
# Out:
# La columna 'Total Flights' es de tipo int64.
# El número total de valores únicos es de 33.
# Hay muchos valores únicos, aquí algunos ejemplos: [ 3 14  6  0 15 11 12 10  8  9  7  5 16  2  1 17 13 22  4 19]
# --------------------------------------------------------------------------
# return - stats dict:
# {'min': np.int64(0),
#  'max': np.int64(32),
#  'mean': np.float64(5.15),
#  'median': np.float64(1.0),
#  'std': np.float64(6.52),
#  'percentil_25': np.float64(0.0),
#  'percentil_75': np.float64(10.0)}

# %%
sp_eda.exploracion_num(df_activity,'Distance', graficos=False, mostrar_estadisticas=False, mostrar_outliers=False)
# Out:
# La columna 'Distance' es de tipo int64.
# El número total de valores únicos es de 4746.
# Hay muchos valores únicos, aquí algunos ejemplos: [1521 2030 1200    0  606 2037 4245 1144 3264 2340 1236 3124 2296 2772
#  2944 1100 1332 2082 3399 3128]
# --------------------------------------------------------------------------
# return - stats dict:
# {'min': np.int64(0),
#  'max': np.int64(6293),
#  'mean': np.float64(1208.88),
#  'median': np.float64(488.0),
#  'std': np.float64(1433.16),
#  'percentil_25': np.float64(0.0),
#  'percentil_75': np.float64(2336.0)}

# %%
sp_eda.exploracion_num(df_activity,'Points Accumulated', graficos=False, mostrar_estadisticas=False, mostrar_outliers=False)
# Out:
# La columna 'Points Accumulated' es de tipo float64.
# El número total de valores únicos es de 1549.
# Hay muchos valores únicos, aquí algunos ejemplos: [152. 203. 120.   0.  60. 424. 114. 326. 234. 123. 312. 229. 277. 294.
#  110. 133. 208. 339.  65. 151.]
# --------------------------------------------------------------------------
# return - stats dict:
# {'min': np.float64(0.0),
#  'max': np.float64(676.5),
#  'mean': np.float64(123.69),
#  'median': np.float64(50.0),
#  'std': np.float64(146.6),
#  'percentil_25': np.float64(0.0),
#  'percentil_75': np.float64(239.0)}

# %%
sp_eda.exploracion_num(df_activity,'Points Redeemed', graficos=False, mostrar_estadisticas=False, mostrar_outliers=False)
# Out:
# La columna 'Points Redeemed' es de tipo int64.
# El número total de valores únicos es de 587.
# Hay muchos valores únicos, aquí algunos ejemplos: [  0 341 364 310 445 312 343 366 389 292 447 324 456 409 436 327 322 291
#  323 300]
# --------------------------------------------------------------------------
# return - stats dict:
# {'min': np.int64(0),
#  'max': np.int64(876),
#  'mean': np.float64(30.7),
#  'median': np.float64(0.0),
#  'std': np.float64(125.49),
#  'percentil_25': np.float64(0.0),
#  'percentil_75': np.float64(0.0)}

# %%
sp_eda.exploracion_num(df_activity,'Dollar Cost Points Redeemed', graficos=False, mostrar_estadisticas=False, mostrar_outliers=False)
# Out:
# La columna 'Dollar Cost Points Redeemed' es de tipo int64.
# El número total de valores únicos es de 49.
# Hay muchos valores únicos, aquí algunos ejemplos: [ 0 28 30 25 36 32 24 26 37 33 35 27 31 54 42 29 38 34 39 55]
# --------------------------------------------------------------------------
# return - stats dict:
# {'min': np.int64(0),
#  'max': np.int64(71),
#  'mean': np.float64(2.48),
#  'median': np.float64(0.0),
#  'std': np.float64(10.15),
#  'percentil_25': np.float64(0.0),
#  'percentil_75': np.float64(0.0)}

# %%
df_loyalty = pd.read_csv(r'../Files/Customer Loyalty History.csv', index_col=0)

# %%
df_loyalty.head()
# Out:
#                Country          Province       City Postal Code  Gender  \
# Loyalty Number
# 480934          Canada           Ontario    Toronto     M2Z 4K1  Female
# 549612          Canada           Alberta   Edmonton     T3G 6Y6    Male
# 429460          Canada  British Columbia  Vancouver     V6E 3D9    Male
# 608370          Canada           Ontario    Toronto     P1W 1K4    Male
# 530508          Canada            Quebec       Hull     J8Y 3Z5    Male
#
#                Education    Salary Marital Status Loyalty Card      CLV  \
# Loyalty Number
# 480934          Bachelor   83236.0        Married         Star  3839.14
# 549612           College       NaN       Divorced         Star  3839.61
# 429460           College       NaN         Single         Star  3839.75
# 608370           College       NaN         Single         Star  3839.75
# 530508          Bachelor  103495.0        Married         Star  3842.79
#
# ...

# %%
df_loyalty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16737 entries, 480934 to 652627
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             16737 non-null  object
#  1   Province            16737 non-null  object
#  2   City                16737 non-null  object
#  3   Postal Code         16737 non-null  object
#  4   Gender              16737 non-null  object
#  5   Education           16737 non-null  object
#  6   Salary              12499 non-null  float64
#  7   Marital Status      16737 non-null  object
#  8   Loyalty Card        16737 non-null  object
#  9   CLV                 16737 non-null  float64
#  10  Enrollment Type     16737 non-null  object
#  11  Enrollment Year     16737 non-null  int64
#  12  Enrollment Month    16737 non-null  int64
#  13  Cancellation Year   2067 non-null   float64
#  14  Cancellation Month  2067 non-null   float64
# ...

# %% [markdown]
#  - 'Salary' tiene vastantes valores nulos > faltan datos
#  - 'Cancellation Year' y 'Cancellation Month'  tienen nivel bajo de nulos

# %%
sp_eda.exploracion_basica(df_loyalty)
# Out:
# ### Información general del DataFrame ###
# Forma (filas, columnas): (16737, 15)
# Columnas: ['Country', 'Province', 'City', 'Postal Code', 'Gender', 'Education', 'Salary', 'Marital Status', 'Loyalty Card', 'CLV', 'Enrollment Type', 'Enrollment Year', 'Enrollment Month', 'Cancellation Year', 'Cancellation Month']
#
# Resumen info():
# <class 'pandas.core.frame.DataFrame'>
# Index: 16737 entries, 480934 to 652627
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             16737 non-null  object
#  1   Province            16737 non-null  object
#  2   City                16737 non-null  object
#  3   Postal Code         16737 non-null  object
#  4   Gender              16737 non-null  object
#  5   Education           16737 non-null  object
#  6   Salary              12499 non-null  float64
#  7   Marital Status      16737 non-null  object
# ...

# %% [markdown]
# Categoricos

# %%
sp_eda.exploracion_cat(df_loyalty,'Country', graficos=False, mostrar_tablas=False, top=10, detectar_raras=True)
# Out:
# --------------------------------------------------------------------------
#
# 📊 Exploración categórica de 'Country':
#  - Moda: Canada
#  - Cardinalidad (nº de categorías distintas): 1
# --------------------------------------------------------------------------
#
# 🔍 Categorías raras (< 1.0%): 0
# {'moda': 'Canada',
#  'cardinalidad': 1,
#  'frecuencias_abs': Country
#  Canada    16737
#  Name: count, dtype: int64,
#  'frecuencias_rel': Country
#  Canada    100.0
#  Name: proportion, dtype: float64,
#  'categorias_raras': Series([], Name: proportion, dtype: float64)}

# %%
sp_eda.exploracion_cat(df_loyalty,'Province', graficos=True, mostrar_tablas=True, top=10, detectar_raras=True)
# Out:
# --------------------------------------------------------------------------
#
# 📊 Exploración categórica de 'Province':
#  - Moda: Ontario
#  - Cardinalidad (nº de categorías distintas): 11
# --------------------------------------------------------------------------
#
# Frecuencias absolutas (completas):
# Province
# Ontario                 5404
# British Columbia        4409
# Quebec                  3300
# Alberta                  969
# Manitoba                 658
# New Brunswick            636
# Nova Scotia              518
# Saskatchewan             409
# Newfoundland             258
# Yukon                    110
# Prince Edward Island      66
# Name: count, dtype: int64
# Frecuencias relativas (%):
# Province
# Ontario                 32.29
# British Columbia        26.34
# Quebec                  19.72
# Alberta                  5.79
# Manitoba                 3.93
# New Brunswick            3.80
# Nova Scotia              3.09
# Saskatchewan             2.44
# ...

# %%
sp_eda.exploracion_cat(df_loyalty,'City', graficos=False, mostrar_tablas=False, top=10, detectar_raras=True)
# Out:
# --------------------------------------------------------------------------
#
# 📊 Exploración categórica de 'City':
#  - Moda: Toronto
#  - Cardinalidad (nº de categorías distintas): 29
# --------------------------------------------------------------------------
#
# 🔍 Categorías raras (< 1.0%): 4
# City
# Peace River      0.68
# Whitehorse       0.66
# Kelowna          0.53
# Charlottetown    0.39
# Name: proportion, dtype: float64
# {'moda': 'Toronto',
#  'cardinalidad': 29,
#  'frecuencias_abs': City
#  Toronto           3351
#  Vancouver         2582
#  Montreal          2059
#  Winnipeg           658
#  Whistler           582
#  Halifax            518
#  Ottawa             509
#  Trenton            486
#  Edmonton           486
#  Quebec City        485
#  Dawson Creek       444
#  Fredericton        425
#  Regina             409
#  Kingston           401
#  Tremblant          398
#  Victoria           389
#  Hull               358
#  West Vancouver     324
# ...

# %%
sp_eda.exploracion_cat(df_loyalty,'Postal Code', graficos=False, mostrar_tablas=False, top=10, detectar_raras=True)
# Out:
# --------------------------------------------------------------------------
#
# 📊 Exploración categórica de 'Postal Code':
#  - Moda: V6E 3D9
#  - Cardinalidad (nº de categorías distintas): 55
# --------------------------------------------------------------------------
#
# 🔍 Categorías raras (< 1.0%): 12
# Postal Code
# M2M 6J7    0.91
# R6Y 4T5    0.85
# M2P 4F6    0.75
# K1G 4Z0    0.72
# T9O 2W2    0.68
# Y2K 6R0    0.66
# R3R 3T4    0.60
# H3T 8L4    0.53
# V09 2E9    0.53
# C1A 6E8    0.39
# H3J 5I6    0.04
# M3R 4K8    0.02
# Name: proportion, dtype: float64
# {'moda': 'V6E 3D9',
#  'cardinalidad': 55,
#  'frecuencias_abs': Postal Code
#  V6E 3D9    911
#  V5R 1W3    684
#  V6T 1Y8    582
#  V6E 3Z3    544
#  M2M 7K8    534
#  P1J 8T7    500
#  H2T 9K8    499
#  K8V 4B2    486
#  G1B 3L5    485
#  H2T 2J6    446
#  U5I 4F1    444
#  V1E 4R6    443
#  E3B 2H2    425
#  R2C 0M5    415
#  M9K 2P4    401
#  H5Y 2S9    398
#  V10 6T5    389
#  K1F 2R2    389
#  H2Y 2W2    365
# ...

# %%
sp_eda.exploracion_cat(df_loyalty,'Gender', graficos=True, mostrar_tablas=False, top=10, detectar_raras=True)
# Out:
# --------------------------------------------------------------------------
#
# 📊 Exploración categórica de 'Gender':
#  - Moda: Female
#  - Cardinalidad (nº de categorías distintas): 2
# --------------------------------------------------------------------------
#
# 🔍 Categorías raras (< 1.0%): 0
# --------------------------------------------------------------------------
# {'moda': 'Female',
#  'cardinalidad': 2,
#  'frecuencias_abs': Gender
#  Female    8410
#  Male      8327
#  Name: count, dtype: int64,
#  'frecuencias_rel': Gender
#  Female    50.25
#  Male      49.75
#  Name: proportion, dtype: float64,
#  'categorias_raras': Series([], Name: proportion, dtype: float64)}

# %%
sp_eda.exploracion_cat(df_loyalty,'Education', graficos=False, mostrar_tablas=False, top=10, detectar_raras=True)
# Out:
# --------------------------------------------------------------------------
#
# 📊 Exploración categórica de 'Education':
#  - Moda: Bachelor
#  - Cardinalidad (nº de categorías distintas): 5
# --------------------------------------------------------------------------
#
# 🔍 Categorías raras (< 1.0%): 0
# {'moda': 'Bachelor',
#  'cardinalidad': 5,
#  'frecuencias_abs': Education
#  Bachelor                10475
#  College                  4238
#  High School or Below      782
#  Doctor                    734
#  Master                    508
#  Name: count, dtype: int64,
#  'frecuencias_rel': Education
#  Bachelor                62.59
#  College                 25.32
#  High School or Below     4.67
#  Doctor                   4.39
#  Master                   3.04
#  Name: proportion, dtype: float64,
#  'categorias_raras': Series([], Name: proportion, dtype: float64)}

# %%
sp_eda.exploracion_cat(df_loyalty,'Marital Status', graficos=True, mostrar_tablas=False, top=10, detectar_raras=True)
# Out:
# --------------------------------------------------------------------------
#
# 📊 Exploración categórica de 'Marital Status':
#  - Moda: Married
#  - Cardinalidad (nº de categorías distintas): 3
# --------------------------------------------------------------------------
#
# 🔍 Categorías raras (< 1.0%): 0
# --------------------------------------------------------------------------
# {'moda': 'Married',
#  'cardinalidad': 3,
#  'frecuencias_abs': Marital Status
#  Married     9735
#  Single      4484
#  Divorced    2518
#  Name: count, dtype: int64,
#  'frecuencias_rel': Marital Status
#  Married     58.16
#  Single      26.79
#  Divorced    15.04
#  Name: proportion, dtype: float64,
#  'categorias_raras': Series([], Name: proportion, dtype: float64)}

# %%
sp_eda.exploracion_cat(df_loyalty,'Loyalty Card', graficos=False, mostrar_tablas=False, top=10, detectar_raras=True)
# Out:
# --------------------------------------------------------------------------
#
# 📊 Exploración categórica de 'Loyalty Card':
#  - Moda: Star
#  - Cardinalidad (nº de categorías distintas): 3
# --------------------------------------------------------------------------
#
# 🔍 Categorías raras (< 1.0%): 0
# {'moda': 'Star',
#  'cardinalidad': 3,
#  'frecuencias_abs': Loyalty Card
#  Star      7637
#  Nova      5671
#  Aurora    3429
#  Name: count, dtype: int64,
#  'frecuencias_rel': Loyalty Card
#  Star      45.63
#  Nova      33.88
#  Aurora    20.49
#  Name: proportion, dtype: float64,
#  'categorias_raras': Series([], Name: proportion, dtype: float64)}

# %%
sp_eda.exploracion_cat(df_loyalty,'Enrollment Type', graficos=False, mostrar_tablas=False, top=10, detectar_raras=True)
# Out:
# --------------------------------------------------------------------------
#
# 📊 Exploración categórica de 'Enrollment Type':
#  - Moda: Standard
#  - Cardinalidad (nº de categorías distintas): 2
# --------------------------------------------------------------------------
#
# 🔍 Categorías raras (< 1.0%): 0
# {'moda': 'Standard',
#  'cardinalidad': 2,
#  'frecuencias_abs': Enrollment Type
#  Standard          15766
#  2018 Promotion      971
#  Name: count, dtype: int64,
#  'frecuencias_rel': Enrollment Type
#  Standard          94.2
#  2018 Promotion     5.8
#  Name: proportion, dtype: float64,
#  'categorias_raras': Series([], Name: proportion, dtype: float64)}

# %% [markdown]
# Numericos

# %%
sp_eda.exploracion_num(df_loyalty,'Salary', graficos=True, mostrar_estadisticas=True, mostrar_outliers=True)
# Out:
# La columna 'Salary' es de tipo float64.
# El número total de valores únicos es de 5890.
# Hay muchos valores únicos, aquí algunos ejemplos: [ 83236.     nan 103495.  51124. 100159.  66444.  49618.  90175. 128118.
#   94092.  89062. 102400.  98629.  63795.  54890.  51375.  70222.  40736.
#   75861.  69835.]
# --------------------------------------------------------------------------
#
# 📊 Exploración numérica de 'Salary':
#  - min: -58486.0
#  - max: 407228.0
#  - mean: 79245.61
#  - median: 73455.0
#  - std: 35008.3
#  - percentil_25: 59246.5
#  - percentil_75: 88517.5
# --------------------------------------------------------------------------
#
# Tabla completa describe():
# count     12499.000000
# mean      79245.609409
# std       35008.297285
# min      -58486.000000
# 25%       59246.500000
# 50%       73455.000000
# 75%       88517.500000
# max      407228.000000
# Name: Salary, dtype: float64
# --------------------------------------------------------------------------
#
# ...

# %%
sp_eda.exploracion_num(df_loyalty,'CLV', graficos=True, mostrar_estadisticas=True, mostrar_outliers=False)
# Out:
# La columna 'CLV' es de tipo float64.
# El número total de valores únicos es de 7984.
# Hay muchos valores únicos, aquí algunos ejemplos: [3839.14 3839.61 3839.75 3842.79 3844.57 3857.95 3861.49 3863.31 3864.78
#  3867.97 3871.07 3872.22 3873.65 3878.77 5303.76 3885.46 3886.5  3886.65
#  3887.32 3890.87]
# --------------------------------------------------------------------------
#
# 📊 Exploración numérica de 'CLV':
#  - min: 1898.01
#  - max: 83325.38
#  - mean: 7988.9
#  - median: 5780.18
#  - std: 6860.98
#  - percentil_25: 3980.84
#  - percentil_75: 8940.58
# --------------------------------------------------------------------------
#
# Tabla completa describe():
# count    16737.000000
# mean      7988.896536
# std       6860.982280
# min       1898.010000
# 25%       3980.840000
# 50%       5780.180000
# 75%       8940.580000
# max      83325.380000
# Name: CLV, dtype: float64
# --------------------------------------------------------------------------
# ...

# %%
sp_eda.exploracion_num(df_loyalty,'Enrollment Year', graficos=False, mostrar_estadisticas=False, mostrar_outliers=False)
# Out:
# La columna 'Enrollment Year' es de tipo int64.
# El número total de valores únicos es de 7.
# Los valores únicos son: [2016 2014 2013 2012 2015 2018 2017]
# --------------------------------------------------------------------------
# return - stats dict:
# {'min': np.int64(2012),
#  'max': np.int64(2018),
#  'mean': np.float64(2015.25),
#  'median': np.float64(2015.0),
#  'std': np.float64(1.98),
#  'percentil_25': np.float64(2014.0),
#  'percentil_75': np.float64(2017.0)}

# %%
sp_eda.exploracion_num(df_loyalty,'Enrollment Month', graficos=False, mostrar_estadisticas=False, mostrar_outliers=True)
# Out:
# La columna 'Enrollment Month' es de tipo int64.
# El número total de valores únicos es de 12.
# Los valores únicos son: [ 2  3  7 10  5  6 12  1 11  8  4  9]
#
# 🔍 Número de outliers detectados: 0
# Conteo de outliers por valor único:
# Series([], Name: count, dtype: int64)
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# return - stats dict:
# {'min': np.int64(1),
#  'max': np.int64(12),
#  'mean': np.float64(6.67),
#  'median': np.float64(7.0),
#  'std': np.float64(3.4),
#  'percentil_25': np.float64(4.0),
#  'percentil_75': np.float64(10.0),
#  'outliers_count': 0,
#  'outliers_unique_values': {}}

# %%
## La forma mas eficiente de unir los dos dataframes es mediante un merge. La columna común es 'Loyalty Number', que está en ambos dataframes.

# %%
df_merged = pd.merge(df_activity, df_loyalty, on='Loyalty Number', how='left')

# %%
#porcentaje de nulos por columna
df_nulos = pd.DataFrame(df_merged.isna().sum()*100/df_merged.shape[0])

df_nulos
# Out:
#                                      0
# Year                          0.000000
# Month                         0.000000
# Flights Booked                0.000000
# Flights with Companions       0.000000
# Total Flights                 0.000000
# Distance                      0.000000
# Points Accumulated            0.000000
# Points Redeemed               0.000000
# Dollar Cost Points Redeemed   0.000000
# Country                       0.000000
# Province                      0.000000
# City                          0.000000
# Postal Code                   0.000000
# Gender                        0.000000
# Education                     0.000000
# Salary                       25.312112
# Marital Status                0.000000
# Loyalty Card                  0.000000
# CLV                           0.000000
# Enrollment Type               0.000000
# Enrollment Year               0.000000
# Enrollment Month              0.000000
# Cancellation Year            87.657535
# ...

# %%
df_merged.head(3)
# Out:
#                 Year  Month  Flights Booked  Flights with Companions  \
# Loyalty Number
# 100018          2017      1               3                        0
# 100102          2017      1              10                        4
# 100140          2017      1               6                        0
#
#                 Total Flights  Distance  Points Accumulated  Points Redeemed  \
# Loyalty Number
# 100018                      3      1521               152.0                0
# 100102                     14      2030               203.0                0
# 100140                      6      1200               120.0                0
#
#                 Dollar Cost Points Redeemed Country          Province  \
# Loyalty Number
# 100018                                    0  Canada           Alberta
# 100102                                    0  Canada           Ontario
# 100140                                    0  Canada  British Columbia
#
# ...

# %%
df_merged.duplicated().sum()
# Out:
# np.int64(1864)

# %%
(df_merged[['Distance', 'Points Accumulated', 'Flights Booked', 'Salary', 'CLV']].describe().T)
#uso el discribe para ver las estadísticas básicas de las columnas numéricas
# Out:
#                        count          mean           std       min       25%  \
# Distance            405624.0   1208.880059   1433.155320      0.00      0.00
# Points Accumulated  405624.0    123.692721    146.599831      0.00      0.00
# Flights Booked      405624.0      4.115052      5.225518      0.00      0.00
# Salary              302952.0  79268.825953  34992.133508 -58486.00  59262.00
# CLV                 405624.0   7991.976226   6863.663857   1898.01   3985.32
#
#                          50%       75%        max
# Distance              488.00   2336.00    6293.00
# Points Accumulated     50.00    239.00     676.50
# Flights Booked          1.00      8.00      21.00
# Salary              73479.00  88612.00  407228.00
# CLV                  5776.34   8936.82   83325.38

# %% [markdown]
# Para posibles visualizaciones, establezco tamaño para que todos tengan los mismos tamaños

# %% [markdown]
# valores nulos

# %% [markdown]
# Creo y guardo un nuevo csv para la futura limpieza

# %%
df_merged.to_csv('union.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv(r'../Files/union.csv', index_col=0)

# %%
print(f"Mínimo de Flights Booked: {df['Flights Booked'].min()}")
print(f"Mínimo de Distance: {df['Distance'].min()}")
print(f"Mínimo de Points Accumulated: {df['Points Accumulated'].min()}")
# Out:
# --- 1. Inspección de Rangos de Vuelo (Mínimos) ---
# Mínimo de Flights Booked: 0
# Mínimo de Distance: 0
# Mínimo de Points Accumulated: 0.0

# %%
df['Suma_Vuelos_Verificacion'] = df['Flights Booked'] + df['Flights with Companions']

# %%
df[['Suma_Vuelos_Verificacion', 'Flights Booked', 'Flights with Companions']]
# Out:
#       Suma_Vuelos_Verificacion  Flights Booked  Flights with Companions
# Year
# 2017                         3               3                        0
# 2017                        14              10                        4
# 2017                         6               6                        0
# 2017                         0               0                        0
# 2017                         0               0                        0
# ...                        ...             ...                      ...
# 2018                         0               0                        0
# 2018                         0               0                        0
# 2018                         3               3                        0
# 2018                         0               0                        0
# 2018                         0               0                        0
#
# [405624 rows x 3 columns]

# %% [markdown]
# 🧨 hay que arreglar las inconsistencias ya que el número de vuelos reservados y realizados no son compatibles.

# %%
print(f"Rango de Enrollment Year: {df['Enrollment Year'].min()} - {df['Enrollment Year'].max()}")
print(f"Valores únicos en Gender: {df['Gender'].unique()}")
print(f"Valores únicos en Loyalty Card: {df['Loyalty Card'].unique()}")
print(f"Valores únicos en Marital Status: {df['Marital Status'].unique()}")
# Out:
# Rango de Enrollment Year: 2012 - 2018
# Valores únicos en Gender: ['Female' 'Male']
# Valores únicos en Loyalty Card: ['Aurora' 'Nova' 'Star']
# Valores únicos en Marital Status: ['Married' 'Single' 'Divorced']
